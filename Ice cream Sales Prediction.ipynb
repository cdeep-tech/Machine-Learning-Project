# %% [markdown]
# ### Ice Cream Sales Prediction Project

# %%
# Machine Learning Model Building Steps


# Get the data
# Data Preprocessing
# Build the model
# training & testing
# Deployment

# %%
# Get the data

import pandas as pd
import numpy as np

df = pd.read_csv("SalesData.csv")
df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
""" Data preproceeing Steps
 1. Data Cleaning
 2. Split the data into train & test"""
# Out:
# ' Data preproceeing Steps\n 1. Data Cleaning\n 2. Split the data into train & test'

# %%
# Data CLeaning

df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
# Seperate Features & Label

X=df[["Temperature"]]    # Features
Y=df["Revenue"]          # Label

# %%
X
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
Y
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
# Train & test Data splitting
from sklearn.model_selection import train_test_split

x1,x2,y1,y2 = train_test_split(X,Y,
                 test_size=0.2,
                 random_state=2)

# %%
# Train the model

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x1,y1)
# Out:
# LinearRegression()

# %%
# Test the Model

yp = model.predict(x2)
yp
# Out:
# array([737.28433929, 655.34210146, 710.19407285, 582.46017191,
#        507.28680014, 486.3876242 , 602.74925187, 387.04219595,
#        797.09818519, 596.7684118 , 511.81182359, 520.3750202 ,
#        283.58088772, 484.50622135, 672.15197649, 590.28331158,
#        495.11420717, 493.52056999, 659.28182521, 502.62421805,
#        570.24340507, 354.27310522, 253.08350026, 285.70425206,
#        186.60897774, 368.06474551, 679.38656114, 446.73489391,
#        364.57939171, 591.04601232, 473.86776845, 479.63816308,
#        606.73640118, 551.13094146, 622.8249753 , 400.75348218,
#        486.25215732, 585.34974034, 262.60143898, 547.31477448,
#        531.07744425, 557.3464592 , 410.16005859, 671.26661891,
#        630.7080707 , 677.64854871, 457.30789262, 270.09524251,
#        466.28144952, 527.43538023, 708.79901269, 661.00779647,
#        417.91816957, 477.62829448, 588.38581298, 744.82354441,
#        234.68385401, 296.76671218, 750.02257043, 651.78758079,
#        305.92815815, 738.08564766, 498.81093372, 520.24092364,
#        524.86114116, 510.7825355 , 444.47432266, 470.44827743,
#        538.56849941, 452.49751745, 233.9269748 , 592.93034166,
#        318.36582809, 571.6042904 , 439.00214881, 308.98293315,
#        448.12588902, 892.1411615 , 610.34671225, 414.24517364,
#        939.75081414, 599.77193075, 479.19074809, 448.94462349,
#        537.21779658, 757.6729993 , 378.58549095, 474.69987189,
#        421.26098821, 549.13186193, 640.92289803, 452.50412667,
#        508.7874511 , 424.28493136, 604.31467151, 361.70830647,
#        673.45389241, 891.56911809, 696.87946428, 675.98900406])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(x2, yp)
plt.scatter(x2,y2)

# %%
model.score(x2,y2) * 100
# Out:
# 97.3546292060864

# %%
# Do the Prediction

new = [[100]]

model.predict(new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2184.86564979])
